# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
main_rnn_dir = '/Users/befeltingu/NeuralNetworks/RNN/'

# %%
ravel_trans_matrix = np.load('/Users/befeltingu/NeuralNetworks/RNN/output/raval_trans_prob.npy')

# %%
tensorflow_trans_matrix = np.load(main_rnn_dir + 'output/tensorflow/rnn_prob_trans.npy')
tensorflow_y_labels = np.load(main_rnn_dir + '/output/tensorflow/y_labels.npy')
tensorflow_x_labels = np.load(main_rnn_dir + '/output/tensorflow/x_labels.npy')

# %%
david_trans_matrix = np.load(main_rnn_dir + 'output/david/pmatrix.npy')
david_y_labels = np.load(main_rnn_dir + '/output/david/y_labels.npy')
david_x_labels = np.load(main_rnn_dir + '/output/david/x_labels.npy')

# %%
ravel_df = pd.DataFrame(ravel_trans_matrix[1:],columns=['a', 'ran', 'is', 'dog', 'fast', 'the', 'he'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-325ba6f0bde5> in <module>()
# ----> 1 ravel_df = pd.DataFrame(ravel_trans_matrix[1:],columns=['a', 'ran', 'is', 'dog', 'fast', 'the', 'he'])
#
# /Users/befeltingu/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     253             else:
#     254                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 255                                          copy=copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
#
# /Users/befeltingu/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
#     430             values = _possibly_infer_to_datetimelike(values)
#     431
# ...

# %%
words = pd.Series(['the', 'dog', 'ran', 'fast', 'he', 'is', 'a', 'fast', 'dog'])

# %%
heatmap = sns.heatmap(pandas_df,yticklabels=words,annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f0b6a6c8a690> in <module>()
# ----> 1 heatmap = sns.heatmap(pandas_df,yticklabels=words,annot=True)
#
# NameError: name 'pandas_df' is not defined

# %%
fig = heatmap.get_figure()

# %%
tensorflow_heatmap = sns.heatmap(tensorflow_trans_matrix,yticklabels=tensorflow_y_labels,xticklabels=tensorflow_x_labels,annot=True)

# %%
david_heatmap = sns.heatmap(david_trans_matrix,yticklabels=david_y_labels,xticklabels=david_x_labels,annot=True)
